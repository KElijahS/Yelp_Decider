# %%
# Dependencies
import requests
import json

# Yelp developer API key
from config import ykey

# %%
# Counter for number of users
users = int(input("How many people are choosing:"))
# Out:
# How many people are choosing:4

# %%
# Base URL
base_url = "https://api.yelp.com/v3/businesses/search"

# Parameter definitions
target_price = str(input("How much do you want to spend (1-4, low to high)"))
target_location = str(input("Enter your city:"))
target_radius = (int(input("How far are you willing to drive (number of miles):")))*1609
target_category = str(input("What kind of cuisine are you craving?:"))

# Parameters for URL
params = {
    "location": target_location,
    "radius": target_radius,
    "price": target_price,
    "categories": target_category,
    "term": "restaurants",
}

# Authentification
headers= {"Authorization": "bearer %s" % ykey}


print(target_location)
print(target_category)
print(target_price)
print(target_radius)
# Out:
# How much do you want to spend (1-4, low to high)1,2,3,4
# Enter your city:atlanta
# How far are you willing to drive (number of miles):20
# What kind of cuisine are you craving?:sushi
# atlanta
# sushi
# 1,2,3,4
# 32180

# %%
# Run request and convert to JSON
response = requests.get(url=base_url, params=params, headers=headers)
print(response)
results = response.json()

# Pretty print JSON
print(json.dumps(results, indent=4, sort_keys=True))
# Out:
# <Response [200]>
# {
#     "businesses": [
#         {
#             "alias": "ginya-izakaya-atlanta-4",
#             "categories": [
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 },
#                 {
#                     "alias": "ramen",
#                     "title": "Ramen"
#                 },
#                 {
#                     "alias": "izakaya",
#                     "title": "Izakaya"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.8004825392379,
#                 "longitude": -84.4084178937034
#             },
#             "display_phone": "(470) 355-5621",
#             "distance": 3512.3760278820064,
#             "id": "6wGHem2o7migh4syWmmB8A",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/XKj5-mVls2YBfTH0bCgd5A/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1700 Northside Dr NW",
#                 "address2": "Ste A-5",
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "1700 Northside Dr NW",
#                     "Ste A-5",
#                     "Atlanta, GA 30318"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30318"
#             },
#             "name": "Ginya Izakaya",
#             "phone": "+14703555621",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 507,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/ginya-izakaya-atlanta-4?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "nakato-japanese-restaurant-atlanta-2",
#             "categories": [
#                 {
#                     "alias": "japanese",
#                     "title": "Japanese"
#                 },
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 },
#                 {
#                     "alias": "tapasmallplates",
#                     "title": "Tapas/Small Plates"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.808668,
#                 "longitude": -84.36461
#             },
#             "display_phone": "(404) 873-6582",
#             "distance": 974.3670095125071,
#             "id": "F7d32-PQcfIEX-bAaMjV_Q",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/EMYb3MfYFviscqF1HqJP3g/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1776 Cheshire Bridge Rd NE",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "1776 Cheshire Bridge Rd NE",
#                     "Atlanta, GA 30324"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30324"
#             },
#             "name": "Nakato Japanese Restaurant",
#             "phone": "+14048736582",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 754,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/nakato-japanese-restaurant-atlanta-2?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "nagomiya-atlanta",
#             "categories": [
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.78174294316693,
#                 "longitude": -84.38828271414474
#             },
#             "display_phone": "(404) 975-3851",
#             "distance": 3752.2380457488885,
#             "id": "sPj_tUnN6aOf428wG5_X2Q",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/GvD_Msly8f-_s86llCd8nA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1010 W Peachtree St NW",
#                 "address2": "Ste 400",
#                 "address3": null,
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "1010 W Peachtree St NW",
#                     "Ste 400",
#                     "Atlanta, GA 30309"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30309"
#             },
#             "name": "Nagomiya",
#             "phone": "+14049753851",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 35,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/nagomiya-atlanta?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "silom-thai-and-sushi-atlanta",
#             "categories": [
#                 {
#                     "alias": "thai",
#                     "title": "Thai"
#                 },
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 },
#                 {
#                     "alias": "tapasmallplates",
#                     "title": "Tapas/Small Plates"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.846287,
#                 "longitude": -84.3586822
#             },
#             "display_phone": "(404) 549-3948",
#             "distance": 3928.1797286153587,
#             "id": "qx7-TEoNazwE1BcZLCIJ9w",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/fLtQfwcO6zHJmmguWEfloA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "3345 Lenox Rd NE",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "3345 Lenox Rd NE",
#                     "Atlanta, GA 30326"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30326"
#             },
#             "name": "Silom Thai & Sushi",
#             "phone": "+14045493948",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 196,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/silom-thai-and-sushi-atlanta?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "rays-in-the-city-atlanta",
#             "categories": [
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 },
#                 {
#                     "alias": "tradamerican",
#                     "title": "American (Traditional)"
#                 },
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.7604276519377,
#                 "longitude": -84.3877977142334
#             },
#             "display_phone": "(404) 524-9224",
#             "distance": 6013.798444077958,
#             "id": "JIvAjPUZgQFuo4wb_MdvBw",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/GAZE_mMdglcaCvMUSBjhNQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "240 Peachtree St NW",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "240 Peachtree St NW",
#                     "Atlanta, GA 30303"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30303"
#             },
#             "name": "Ray's in the City",
#             "phone": "+14045249224",
#             "price": "$$$",
#             "rating": 4.0,
#             "review_count": 936,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/rays-in-the-city-atlanta?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "umi-atlanta",
#             "categories": [
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.8394916972822,
#                 "longitude": -84.3821457400918
#             },
#             "display_phone": "(404) 841-0040",
#             "distance": 3026.149286334777,
#             "id": "ooAWQE5DYHv3rsXrM0IvOg",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/QgczGvr360pSlE4Kilrbgw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "3050 Peachtree Rd",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "3050 Peachtree Rd",
#                     "Atlanta, GA 30305"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30305"
#             },
#             "name": "Umi",
#             "phone": "+14048410040",
#             "price": "$$$",
#             "rating": 4.0,
#             "review_count": 649,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/umi-atlanta?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "wagaya-emory-village-atlanta-3",
#             "categories": [
#                 {
#                     "alias": "japanese",
#                     "title": "Japanese"
#                 },
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 },
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.78794,
#                 "longitude": -84.32593
#             },
#             "display_phone": "(678) 949-9278",
#             "distance": 5221.526071238427,
#             "id": "Pl_BSZM-dS1R9v29H0hV_Q",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/AETwQ-7Q-GzC8vEJAslz3Q/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1579 N Decatur Rd NE",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "1579 N Decatur Rd NE",
#                     "Atlanta, GA 30307"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30307"
#             },
#             "name": "Wagaya - Emory Village",
#             "phone": "+16789499278",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 156,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/wagaya-emory-village-atlanta-3?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "co-atlanta-5",
#             "categories": [
#                 {
#                     "alias": "vietnamese",
#                     "title": "Vietnamese"
#                 },
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 },
#                 {
#                     "alias": "noodles",
#                     "title": "Noodles"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.772891,
#                 "longitude": -84.351836
#             },
#             "display_phone": "(404) 474-0262",
#             "distance": 4915.032384235015,
#             "id": "mAbeo_MHU7MF2kv7P0mxYQ",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/ZoMh2BGa_BGNmDqji763-w/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "675 N Highland Ave NE",
#                 "address2": "Ste 6000",
#                 "address3": null,
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "675 N Highland Ave NE",
#                     "Ste 6000",
#                     "Atlanta, GA 30306"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30306"
#             },
#             "name": "CO",
#             "phone": "+14044740262",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 362,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/co-atlanta-5?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "eight-sushi-lounge-atlanta",
#             "categories": [
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 },
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 },
#                 {
#                     "alias": "japanese",
#                     "title": "Japanese"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.78025,
#                 "longitude": -84.41095
#             },
#             "display_phone": "(404) 796-8888",
#             "distance": 5049.21109054938,
#             "id": "_lEHolD7sVt4-SnbuuAgcA",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/YNp01UIdCtW7YdsFTbOITA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "930 Howell Mill Rd NW",
#                 "address2": "Ste B",
#                 "address3": null,
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "930 Howell Mill Rd NW",
#                     "Ste B",
#                     "Atlanta, GA 30318"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30318"
#             },
#             "name": "Eight Sushi Lounge",
#             "phone": "+14047968888",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 1023,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/eight-sushi-lounge-atlanta?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "boruboru-sushi-atlanta",
#             "categories": [
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 },
#                 {
#                     "alias": "poke",
#                     "title": "Poke"
#                 },
#                 {
#                     "alias": "japanese",
#                     "title": "Japanese"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.800721189183,
#                 "longitude": -84.3265157192945
#             },
#             "display_phone": "(404) 458-5518",
#             "distance": 4569.015693951997,
#             "id": "jPBySXO_3jOwdP4M473uXw",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/9VmrZ2Dw3mIJotPioGsI3Q/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1568 Avenue Pl",
#                 "address2": "Ste 160",
#                 "address3": null,
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "1568 Avenue Pl",
#                     "Ste 160",
#                     "Atlanta, GA 30322"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30322"
#             },
#             "name": "Boruboru sushi",
#             "phone": "+14044585518",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 208,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/boruboru-sushi-atlanta?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "wagaya-westside-atlanta",
#             "categories": [
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 },
#                 {
#                     "alias": "ramen",
#                     "title": "Ramen"
#                 },
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.786349,
#                 "longitude": -84.398266
#             },
#             "display_phone": "(470) 575-5799",
#             "distance": 3755.8554774042036,
#             "id": "24--2r1ZEgnmJs5iVVAOgQ",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/BsxgMKpbcp_3aCpvGzsJUw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "339 14th St NW",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "339 14th St NW",
#                     "Atlanta, GA 30318"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30318"
#             },
#             "name": "Wagaya - Westside",
#             "phone": "+14705755799",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 599,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/wagaya-westside-atlanta?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "yoi-yoi-japanese-steakhouse-and-sushi-atlanta-2",
#             "categories": [
#                 {
#                     "alias": "japanese",
#                     "title": "Japanese"
#                 },
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.8104265,
#                 "longitude": -84.4160075
#             },
#             "display_phone": "(404) 351-1788",
#             "distance": 3927.7344283003504,
#             "id": "2ln-fgb6xCCmJ_CzhoPI_w",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/jj3aYpmpNZd1Ca8bxixUTQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "857 Collier Rd",
#                 "address2": "Ste 11",
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "857 Collier Rd",
#                     "Ste 11",
#                     "Atlanta, GA 30318"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30318"
#             },
#             "name": "Yoi Yoi Japanese Steakhouse & Sushi",
#             "phone": "+14043511788",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 276,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/yoi-yoi-japanese-steakhouse-and-sushi-atlanta-2?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "o-ku-sushi-atlanta",
#             "categories": [
#                 {
#                     "alias": "japanese",
#                     "title": "Japanese"
#                 },
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 },
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.78453852212427,
#                 "longitude": -84.41123120223745
#             },
#             "display_phone": "(404) 500-2383",
#             "distance": 4715.947568304695,
#             "id": "KfKW8ZIOOFiZSIVlFgmVtA",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/HzrwWyrhvGIpO9lgNMdf7Q/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1085 Howell Mill Rd",
#                 "address2": "Ste A3",
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "1085 Howell Mill Rd",
#                     "Ste A3",
#                     "Atlanta, GA 30318"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30318"
#             },
#             "name": "O-Ku Sushi",
#             "phone": "+14045002383",
#             "price": "$$$",
#             "rating": 4.0,
#             "review_count": 490,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/o-ku-sushi-atlanta?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "thaicoon-and-sushi-bar-atlanta",
#             "categories": [
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 },
#                 {
#                     "alias": "thai",
#                     "title": "Thai"
#                 },
#                 {
#                     "alias": "japanese",
#                     "title": "Japanese"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.8044395664894,
#                 "longitude": -84.3355759796234
#             },
#             "display_phone": "(404) 817-9805",
#             "distance": 3648.419670596617,
#             "id": "6J-lSviMGkXXPldhncba_Q",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/pzZ7TwGIXCNoXLdeqL2JEQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1799 Briarcliff Rd NE",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "1799 Briarcliff Rd NE",
#                     "Atlanta, GA 30306"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30306"
#             },
#             "name": "Thaicoon & Sushi Bar",
#             "phone": "+14048179805",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 375,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/thaicoon-and-sushi-bar-atlanta?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "ocean-wave-by-harry-and-sons-atlanta-10",
#             "categories": [
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 },
#                 {
#                     "alias": "thai",
#                     "title": "Thai"
#                 },
#                 {
#                     "alias": "asianfusion",
#                     "title": "Asian Fusion"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.7769336,
#                 "longitude": -84.352722
#             },
#             "display_phone": "(404) 873-2009",
#             "distance": 4472.750178662434,
#             "id": "xPNE432uqWzrN2LNEpW5MA",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/1Q2TQaj2F2RNlAvr-a3xLg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "820 N Highland Ave NE",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "820 N Highland Ave NE",
#                     "Atlanta, GA 30306"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30306"
#             },
#             "name": "Ocean Wave By Harry And Sons",
#             "phone": "+14048732009",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 446,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/ocean-wave-by-harry-and-sons-atlanta-10?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "shoya-izakaya-doraville",
#             "categories": [
#                 {
#                     "alias": "japanese",
#                     "title": "Japanese"
#                 },
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.9078676264943,
#                 "longitude": -84.2867246367364
#             },
#             "display_phone": "(770) 457-5555",
#             "distance": 13234.981519309478,
#             "id": "OFEnwG1VDgfa_bgOKPOn3A",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/16XlZ_BLR_h4YkamGNeKvQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "6035 Peachtree Rd",
#                 "address2": "Ste A101",
#                 "address3": "",
#                 "city": "Doraville",
#                 "country": "US",
#                 "display_address": [
#                     "6035 Peachtree Rd",
#                     "Ste A101",
#                     "Doraville, GA 30360"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30360"
#             },
#             "name": "Shoya Izakaya",
#             "phone": "+17704575555",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 951,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/shoya-izakaya-doraville?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "extreme-teriyaki-grill-express-atlanta-4",
#             "categories": [
#                 {
#                     "alias": "japanese",
#                     "title": "Japanese"
#                 },
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.8262452965808,
#                 "longitude": -84.366138651967
#             },
#             "display_phone": "(470) 312-2930",
#             "distance": 1605.7502160981833,
#             "id": "QNYQGTAGsfLDEY-71yuT4A",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/xmT85QEC6u_HJBMmCDE71A/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2625 Piedmont Rd NE",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "2625 Piedmont Rd NE",
#                     "Atlanta, GA 30324"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30324"
#             },
#             "name": "Extreme Teriyaki Grill Express",
#             "phone": "+14703122930",
#             "price": "$",
#             "rating": 4.0,
#             "review_count": 70,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/extreme-teriyaki-grill-express-atlanta-4?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "nova-sushi-bar-and-asian-bistro-atlanta",
#             "categories": [
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 },
#                 {
#                     "alias": "chinese",
#                     "title": "Chinese"
#                 },
#                 {
#                     "alias": "japanese",
#                     "title": "Japanese"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.85299,
#                 "longitude": -84.35853
#             },
#             "display_phone": "(678) 732-3239",
#             "distance": 4687.4522394922515,
#             "id": "z7pfTL0H1b1aymOv61OypA",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/5BSsZ0_37e_oRpy5_n6GXA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "3637 Peachtree Rd",
#                 "address2": "Ste D-1",
#                 "address3": null,
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "3637 Peachtree Rd",
#                     "Ste D-1",
#                     "Atlanta, GA 30319"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30319"
#             },
#             "name": "Nova Sushi Bar & Asian Bistro",
#             "phone": "+16787323239",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 301,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/nova-sushi-bar-and-asian-bistro-atlanta?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "mali-restaurant-atlanta-2",
#             "categories": [
#                 {
#                     "alias": "thai",
#                     "title": "Thai"
#                 },
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.7874551,
#                 "longitude": -84.3557158
#             },
#             "display_phone": "(404) 874-1411",
#             "distance": 3319.8098735813996,
#             "id": "vEEBrJniHdEfnjOb77nHtw",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/NrRMQEJJlYyGwtvRhnaj0A/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "961 Amsterdam Ave NE",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "961 Amsterdam Ave NE",
#                     "Atlanta, GA 30306"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30306"
#             },
#             "name": "Mali Restaurant",
#             "phone": "+14048741411",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 404,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/mali-restaurant-atlanta-2?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "himitsu-atlanta",
#             "categories": [
#                 {
#                     "alias": "japanese",
#                     "title": "Japanese"
#                 },
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.838793,
#                 "longitude": -84.381068
#             },
#             "display_phone": "(404) 257-6693",
#             "distance": 2926.228256451363,
#             "id": "_zmYwKxSJJUKNNJO8yinww",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/6LogPJHZi__oEZgl5rIy6w/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "3050 Peachtree Rd NW",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "3050 Peachtree Rd NW",
#                     "Atlanta, GA 30305"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30305"
#             },
#             "name": "Himitsu",
#             "phone": "+14042576693",
#             "price": "$$$",
#             "rating": 3.5,
#             "review_count": 72,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/himitsu-atlanta?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         }
#     ],
#     "region": {
#         "center": {
#             "latitude": 33.81321311652279,
#             "longitude": -84.37362670898438
#         }
#     },
#     "total": 89
# }
