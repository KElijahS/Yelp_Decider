# %%
# Dependencies
import requests
import json

# Yelp developer API key
from config import ykey

# %%
# Counter for number of users
users = int(input("How many people are choosing: "))
# Out:
# How many people are choosing: 3

# %%
# Base URL
base_url = "https://api.yelp.com/v3/businesses/search"

# Parameter definitions
# If statements for price index
target_price = str(input("How much do you want to spend (1-4, low to high): "))
if target_price == "4":
    target_price = "1,2,3,4"
elif target_price == "3":
    target_price = "1,2,3"
elif target_price == "2":
    target_price = "1,2"
else :
    target_price = "1"

target_location = str(input("Enter your city: "))
target_radius = (int(input("How far are you willing to drive (number of miles): ")))*1609
target_category = (str(input("What kind of cuisine are you craving?: "))).lower()

# Parameters for URL
params = {
    "location": target_location,
    "radius": target_radius,
    "price": target_price,
    "categories": target_category,
    "term": "restaurants",
}

# Authentification
headers= {"Authorization": "bearer %s" % ykey}


print(target_location)
print(target_category)
print(target_price)
print(target_radius)
# Out:
# How much do you want to spend (1-4, low to high): 3
# Enter your city: Atlanta
# How far are you willing to drive (number of miles): 10
# What kind of cuisine are you craving?: Steak
# Atlanta
# steak
# 1,2,3
# 16090

# %%
# Run request and convert to JSON
response = requests.get(url=base_url, params=params, headers=headers)
print(response)
results = response.json()

# Pretty print JSON
print(json.dumps(results, indent=4, sort_keys=True))
# Out:
# <Response [200]>
# {
#     "businesses": [
#         {
#             "alias": "nowaks-atlanta-2",
#             "categories": [
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.7928146,
#                 "longitude": -84.3517062
#             },
#             "display_phone": "(678) 705-4231",
#             "distance": 3045.027612236466,
#             "id": "z1RxkGJGGwK1LJnxhspVwA",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/qAVG-cbPPldG93FDY0cq1Q/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1397 N Highland Ave",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "1397 N Highland Ave",
#                     "Atlanta, GA 30306"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30306"
#             },
#             "name": "Nowak's",
#             "phone": "+16787054231",
#             "price": "$$$",
#             "rating": 4.0,
#             "review_count": 116,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/nowaks-atlanta-2?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "kr-steakbar-atlanta",
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "italian",
#                     "title": "Italian"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.8176633959101,
#                 "longitude": -84.3762013609024
#             },
#             "display_phone": "(404) 841-8820",
#             "distance": 549.0454080356171,
#             "id": "5NteL0wlyyvdnfQFrbJSdg",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/tVVV-kZJ6opD6eOkArTWdQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "349 Peachtree Hills Ave NE",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "349 Peachtree Hills Ave NE",
#                     "Atlanta, GA 30305"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30305"
#             },
#             "name": "KR SteakBar",
#             "phone": "+14048418820",
#             "price": "$$$",
#             "rating": 4.0,
#             "review_count": 252,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/kr-steakbar-atlanta?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "houstons-restaurant-atlanta-9",
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.81344,
#                 "longitude": -84.39283
#             },
#             "display_phone": "(404) 351-2442",
#             "distance": 1768.2687473023227,
#             "id": "kAQ91NGtE6ZQift0wxRoVQ",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/N5hXwn6mI6QWqv-nz-XlqA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2166 Peachtree Rd NW",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "2166 Peachtree Rd NW",
#                     "Atlanta, GA 30309"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30309"
#             },
#             "name": "Houston's Restaurant",
#             "phone": "+14043512442",
#             "price": "$$",
#             "rating": 3.5,
#             "review_count": 558,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/houstons-restaurant-atlanta-9?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "the-capital-grille-atlanta-2",
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 },
#                 {
#                     "alias": "wine_bars",
#                     "title": "Wine Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.83886166599961,
#                 "longitude": -84.37910263548595
#             },
#             "display_phone": "(404) 262-1162",
#             "distance": 2896.494900503081,
#             "id": "bSy6VVJIdYPza1Bj9_Eicw",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/n1aP9lFDdpb47fIrGR1pfA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "255 E Paces Ferry Rd NE",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "255 E Paces Ferry Rd NE",
#                     "Atlanta, GA 30305"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30305"
#             },
#             "name": "The Capital Grille",
#             "phone": "+14042621162",
#             "price": "$$$",
#             "rating": 4.5,
#             "review_count": 496,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/the-capital-grille-atlanta-2?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "houstons-restaurant-atlanta-7",
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "tradamerican",
#                     "title": "American (Traditional)"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.8512993187976,
#                 "longitude": -84.4299898461716
#             },
#             "display_phone": "(404) 262-7130",
#             "distance": 6711.045409386092,
#             "id": "4htHyo30Fb6yzrtMHd1U_g",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/RUhn7nNp8PYUw6ThOp9Xkg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "3539 Northside Pkwy NW",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "3539 Northside Pkwy NW",
#                     "Atlanta, GA 30327"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30327"
#             },
#             "name": "Houston's Restaurant",
#             "phone": "+14042627130",
#             "price": "$$",
#             "rating": 3.5,
#             "review_count": 352,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/houstons-restaurant-atlanta-7?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "thrill-korean-steak-and-bar-sandy-springs-3",
#             "categories": [
#                 {
#                     "alias": "korean",
#                     "title": "Korean"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.917761,
#                 "longitude": -84.381834
#             },
#             "display_phone": "(404) 343-1823",
#             "distance": 11649.853003730183,
#             "id": "JnNdEhN7Ixr4NcsbvVZ0Nw",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/92CCiPQatblFmeIdMWZpGQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "5958 Roswell Rd",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Sandy Springs",
#                 "country": "US",
#                 "display_address": [
#                     "5958 Roswell Rd",
#                     "Sandy Springs, GA 30328"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30328"
#             },
#             "name": "Thrill Korean Steak and Bar",
#             "phone": "+14043431823",
#             "price": "$$$",
#             "rating": 4.5,
#             "review_count": 412,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/thrill-korean-steak-and-bar-sandy-springs-3?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "arnettes-chop-shop-brookhaven",
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.86536,
#                 "longitude": -84.3356
#             },
#             "display_phone": "",
#             "distance": 6759.282360454659,
#             "id": "5s5_DbP2EKJtn2SQ-moZNg",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/RZNCXT-5oJIrKOsZZFsKtw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2700 Apple Valley Rd NE",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Brookhaven",
#                 "country": "US",
#                 "display_address": [
#                     "2700 Apple Valley Rd NE",
#                     "Brookhaven, GA 30319"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30319"
#             },
#             "name": "Arnette's Chop Shop",
#             "phone": "",
#             "price": "$$$",
#             "rating": 4.0,
#             "review_count": 164,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/arnettes-chop-shop-brookhaven?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "yoi-yoi-japanese-steakhouse-and-sushi-atlanta-2",
#             "categories": [
#                 {
#                     "alias": "japanese",
#                     "title": "Japanese"
#                 },
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.8104265,
#                 "longitude": -84.4160075
#             },
#             "display_phone": "(404) 351-1788",
#             "distance": 3927.7344283003504,
#             "id": "2ln-fgb6xCCmJ_CzhoPI_w",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/jj3aYpmpNZd1Ca8bxixUTQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "857 Collier Rd",
#                 "address2": "Ste 11",
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "857 Collier Rd",
#                     "Ste 11",
#                     "Atlanta, GA 30318"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30318"
#             },
#             "name": "Yoi Yoi Japanese Steakhouse & Sushi",
#             "phone": "+14043511788",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 276,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/yoi-yoi-japanese-steakhouse-and-sushi-atlanta-2?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "teds-montana-grill-luckie-street-atlanta",
#             "categories": [
#                 {
#                     "alias": "burgers",
#                     "title": "Burgers"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.75879,
#                 "longitude": -84.39054
#             },
#             "display_phone": "(404) 521-9796",
#             "distance": 6268.371086053397,
#             "id": "AUV7Ocno9T8_qPlFeRSziA",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/RLxuA1550Som93bi7uzuiw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "133 Luckie St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "133 Luckie St",
#                     "Atlanta, GA 30303"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30303"
#             },
#             "name": "Ted's Montana Grill - Luckie Street",
#             "phone": "+14045219796",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 904,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/teds-montana-grill-luckie-street-atlanta?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "stk-steakhouse-atlanta-2",
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.784176,
#                 "longitude": -84.38283
#             },
#             "display_phone": "(404) 793-0144",
#             "distance": 3338.8906286384445,
#             "id": "_iqFvc3zToL08WZrNeFP3Q",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/cHKMsDThzTVpoRqS39lPXA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1075 Peachtree St NE",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "1075 Peachtree St NE",
#                     "Atlanta, GA 30309"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30309"
#             },
#             "name": "STK Steakhouse",
#             "phone": "+14047930144",
#             "price": "$$$",
#             "rating": 3.5,
#             "review_count": 1387,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/stk-steakhouse-atlanta-2?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "iron-age-korean-steak-house-sandy-springs-2",
#             "categories": [
#                 {
#                     "alias": "korean",
#                     "title": "Korean"
#                 },
#                 {
#                     "alias": "bbq",
#                     "title": "Barbeque"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.90797,
#                 "longitude": -84.380293
#             },
#             "display_phone": "(678) 974-5075",
#             "distance": 10554.437397985317,
#             "id": "9k8Fo7TIIMi8LrwekRVtLQ",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/NDppRr8kRyHngRUsFYLnwA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "5600 Roswell Rd",
#                 "address2": "F290",
#                 "address3": null,
#                 "city": "Sandy Springs",
#                 "country": "US",
#                 "display_address": [
#                     "5600 Roswell Rd",
#                     "F290",
#                     "Sandy Springs, GA 30342"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30342"
#             },
#             "name": "Iron Age Korean Steak House",
#             "phone": "+16789745075",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 364,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/iron-age-korean-steak-house-sandy-springs-2?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "bayou-q-atlanta-2",
#             "categories": [
#                 {
#                     "alias": "cajun",
#                     "title": "Cajun/Creole"
#                 },
#                 {
#                     "alias": "bbq",
#                     "title": "Barbeque"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.880394,
#                 "longitude": -84.462941
#             },
#             "display_phone": "(770) 850-1987",
#             "distance": 11123.480937435343,
#             "id": "cebrbxY7VYhL_Z2qjasPNA",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/nVAIwvYWkNBg1UeFRNZZkw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2960 Cobb Pkwy",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "2960 Cobb Pkwy",
#                     "Atlanta, GA 30339"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30339"
#             },
#             "name": "Bayou\u2019Q",
#             "phone": "+17708501987",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 59,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/bayou-q-atlanta-2?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "park-75-restaurant-atlanta-3",
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.7863614206531,
#                 "longitude": -84.3853533267975
#             },
#             "display_phone": "(404) 253-3840",
#             "distance": 3176.3044108782638,
#             "id": "tbfbSDu347UPplagdAVuIw",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/gOHSIXWQwreznMUA0Yd54g/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "75 14th St NE",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "75 14th St NE",
#                     "Atlanta, GA 30309"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30309"
#             },
#             "name": "Park 75 Restaurant",
#             "phone": "+14042533840",
#             "price": "$$$",
#             "rating": 4.0,
#             "review_count": 90,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/park-75-restaurant-atlanta-3?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "stoney-river-steakhouse-and-grill-atlanta-2",
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.881454,
#                 "longitude": -84.469193
#             },
#             "display_phone": "(678) 305-9229",
#             "distance": 11639.09411538567,
#             "id": "d-Gv5j_7aANsX0kYyOYQ9w",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/aP4-VHdO967MKzNC2Phh0A/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2860 Cumberland Mall SE",
#                 "address2": "Ste 1640",
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "2860 Cumberland Mall SE",
#                     "Ste 1640",
#                     "Atlanta, GA 30339"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30339"
#             },
#             "name": "Stoney River Steakhouse and Grill",
#             "phone": "+16783059229",
#             "price": "$$$",
#             "rating": 4.0,
#             "review_count": 489,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/stoney-river-steakhouse-and-grill-atlanta-2?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "little-alley-steak-buckhead-atlanta-3",
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.85172,
#                 "longitude": -84.36595
#             },
#             "display_phone": "(404) 254-1899",
#             "distance": 4369.366352923529,
#             "id": "O6N-bLdqxHhOv3f8jGLqRw",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/wZb6CmSxMks2aIX_7my91g/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "3500 Lenox Rd NE",
#                 "address2": "Ste 100",
#                 "address3": null,
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "3500 Lenox Rd NE",
#                     "Ste 100",
#                     "Atlanta, GA 30326"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30326"
#             },
#             "name": "Little Alley Steak - Buckhead",
#             "phone": "+14042541899",
#             "price": "$$$",
#             "rating": 3.5,
#             "review_count": 349,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/little-alley-steak-buckhead-atlanta-3?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "alluvia-atlanta",
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.7792437535146,
#                 "longitude": -84.3882172554731
#             },
#             "display_phone": "(404) 892-3037",
#             "distance": 4010.6263747429525,
#             "id": "R2Z5PCn1aLb3Dy90Mw5eFQ",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/z-9XNGOWa8o4T-AUnCkjkg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "887 Spring St NW",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "887 Spring St NW",
#                     "Atlanta, GA 30308"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30308"
#             },
#             "name": "Alluvia",
#             "phone": "+14048923037",
#             "price": "$$$",
#             "rating": 4.5,
#             "review_count": 7,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/alluvia-atlanta?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "dantannas-atlanta",
#             "categories": [
#                 {
#                     "alias": "sportsbars",
#                     "title": "Sports Bars"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.84744145917,
#                 "longitude": -84.3650990123032
#             },
#             "display_phone": "(404) 760-8873",
#             "distance": 3886.669046878542,
#             "id": "TRAcklO5_GTXr2VkaQRjgw",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/nzCTKe7CTiZIEdG3hZmk5w/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "3400 Around Lenox Rd NE",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "3400 Around Lenox Rd NE",
#                     "Atlanta, GA 30326"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30326"
#             },
#             "name": "Dantanna's",
#             "phone": "+14047608873",
#             "price": "$$",
#             "rating": 3.5,
#             "review_count": 663,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/dantannas-atlanta?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "highland-tap-atlanta",
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.7825343,
#                 "longitude": -84.3545192
#             },
#             "display_phone": "(404) 875-3673",
#             "distance": 3827.2277650398782,
#             "id": "tfGXKEGtiuo4YB3ocK-ywQ",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/eUmVa91e6IUSxUyiBLhcIQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1026 N Highland Ave NE",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "1026 N Highland Ave NE",
#                     "Atlanta, GA 30306"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30306"
#             },
#             "name": "Highland Tap",
#             "phone": "+14048753673",
#             "price": "$$",
#             "rating": 3.5,
#             "review_count": 321,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/highland-tap-atlanta?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "rays-on-the-river-sandy-springs-2",
#             "categories": [
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.90050535752024,
#                 "longitude": -84.440807
#             },
#             "display_phone": "(770) 955-1187",
#             "distance": 11519.43215053877,
#             "id": "yO0dy-IsS0EiXuzNA8zvAQ",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/ziLdH3HbW3vjN0PZ4_bH3g/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "6700 Powers Ferry Rd",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Sandy Springs",
#                 "country": "US",
#                 "display_address": [
#                     "6700 Powers Ferry Rd",
#                     "Sandy Springs, GA 30339"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30339"
#             },
#             "name": "Ray's On the River",
#             "phone": "+17709551187",
#             "price": "$$$",
#             "rating": 4.0,
#             "review_count": 1079,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/rays-on-the-river-sandy-springs-2?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         },
#         {
#             "alias": "del-friscos-grille-atlanta",
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "wine_bars",
#                     "title": "Wine Bars"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 33.8489524,
#                 "longitude": -84.3664042
#             },
#             "display_phone": "(404) 537-2828",
#             "distance": 4029.629297004707,
#             "id": "vQvQ1o1uK05TLxIRK-01qQ",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/I8TVOQ5BK_KrEdPrXyKFLQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "3376 Peachtree Rd NE",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Atlanta",
#                 "country": "US",
#                 "display_address": [
#                     "3376 Peachtree Rd NE",
#                     "Atlanta, GA 30326"
#                 ],
#                 "state": "GA",
#                 "zip_code": "30326"
#             },
#             "name": "Del Frisco's Grille",
#             "phone": "+14045372828",
#             "price": "$$$",
#             "rating": 3.0,
#             "review_count": 670,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/del-friscos-grille-atlanta?adjust_creative=32s8E1kzoTkc6_AU-o7L2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=32s8E1kzoTkc6_AU-o7L2g"
#         }
#     ],
#     "region": {
#         "center": {
#             "latitude": 33.81321311652279,
#             "longitude": -84.37362670898438
#         }
#     },
#     "total": 46
# }
